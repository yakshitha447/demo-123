# %% [markdown]
# <a href="https://colab.research.google.com/github/yakshitha447/demo-123/blob/master/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
      'First':['Aryan','Rohan','Riya','Yash','Siddini'],
      'Lastname':['Singh','Agarwal','Shah','Bhatia','Khanna'],
      'Type':['Full_time Employee','Intern','Full_time Employee','Part_time Employee','Full_time Employee'],
      'Department':['Administration','Technical','Administration','Technical','Technical'],
      'Yoe':[3,5,6,7,6],
      'Salary':[20000,5000,10000,10000,20000]
     }
df=pd.DataFrame(data)
print(df)
table=pd.pivot_table(df,index=['Type','Department'],
values='Salary',aggfunc='mean')
print(table)
table1=pd.pivot_table(df,index=['Type'],
values='Salary',aggfunc=['sum','mean'])
print(table1)
table2=pd.pivot_table(df,index=['Type'],
values='Salary',aggfunc=['count'])
print(table2)
table3=pd.pivot_table(df,index=['Type'],
values='Salary',aggfunc=['std'])
print(table3)
# Out:
#      First Lastname                Type      Department  Yoe  Salary
# 0    Aryan    Singh  Full_time Employee  Administration    3   20000
# 1    Rohan  Agarwal              Intern       Technical    5    5000
# 2     Riya     Shah  Full_time Employee  Administration    6   10000
# 3     Yash   Bhatia  Part_time Employee       Technical    7   10000
# 4  Siddini   Khanna  Full_time Employee       Technical    6   20000
#                                     Salary
# Type               Department
# Full_time Employee Administration  15000.0
#                    Technical       20000.0
# Intern             Technical        5000.0
# Part_time Employee Technical       10000.0
#                       sum          mean
#                    Salary        Salary
# Type
# Full_time Employee  50000  16666.666667
# Intern               5000   5000.000000
# Part_time Employee  10000  10000.000000
#                     count
#                    Salary
# Type
# Full_time Employee      3
# ...

# %%
def add4(x):
    return x+4
list1=[4,6,7,8,9]
list2=list(map(add4,list1))
print(list2)
# Out:
# [8, 10, 11, 12, 13]

# %%
def start_with_A(S):
   return S[0]=="A"
fruit=["Apple","banana","pear","apricot","orange"]
map_object=map(start_with_A,fruit)
print(list(map_object))
# Out:
# [True, False, False, False, False]

# %%
def oddeven(x):
  if x%2==0:
    return True
  else:
    return False
list1=[4,5,6,7,8,9]
evenlist=list(filter(oddeven,list1))
print(evenlist)
# Out:
# [4, 6, 8]
